# %% [markdown]
# # George Westinghouse CTE High School: **Computer Science Department**
#
# Course: **Intro to Data Science in Python**

# %% [markdown]
# # **Lab 1D - Zooming Through Data**
#
# Directions: Follow along in Google Colab.  Answer the questions in bold in this word document.  Type your answers in blue font and bolded font.
#
# For extra credit on this lab, answer all questions in the Google Colab file (select the +Text button in Colab). This will allow you to practice making a real report that a manager would expect from you.  (10 pts extra credit)

# %% [markdown]
# The first step for our analysis is to import our libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# The next step is to import our dataset and assign it to a variable called **cdc**

# %%
#load the data and assign it to the variable cdc
cdc = pd.read_csv("https://raw.githubusercontent.com/nschettini/datasets/master/cdc.csv")

# %%
#If you want to see the data table, remove the hashtag below and run the cell.  
cdc
# Out:
#        Unnamed: 0           age  ...              drink_water sunburns
# 0               1  16 years old  ...           1 time per day  0 times
# 1               2  16 years old  ...          2 times per day  0 times
# 2               3  17 years old  ...  4 or more times per day  2 times
# 3               4  17 years old  ...           1 time per day  0 times
# 4               5  16 years old  ...  4 or more times per day  1 times
# ...           ...           ...  ...                      ...      ...
# 15619       15620  15 years old  ...                      NaN      NaN
# 15620       15621  15 years old  ...                      NaN      NaN
# 15621       15622  17 years old  ...                      NaN      NaN
# 15622       15623  15 years old  ...                      NaN      NaN
# 15623       15624  15 years old  ...                      NaN      NaN
#
# [15624 rows x 34 columns]

# %% [markdown]
# **Data with Clarity**
#
#
# * Previously, we've looked at graphs of entire variables (By looking at all of their values).
#  * Doing this is helpful to get a big picture idea of our data. In this lab, we'll learn how to zoom in on our data by learning how to subset.
# * We'll also learn a few ways to manipulate the plots we've been making to make them easier to use for analyses.

# %% [markdown]
# # **Splitting data sets**
#
# * In lab 1B, we learned that we can facet (or split) our data based on a categorical variable.
# * Use the following code in a Code  block (green below)
#
# ---
#
#
# `sns.relplot(x="height", y="weight", hue="gender", sizes=(40, 400), size="race", alpha=.5, palette="muted", height=10, data=cdc)`
#
#
# ---
#
# * **What does the data show?**
# The data shows ...
# The Data shows information from high school students.
# * **What do you think the size command in the code does?**
# The size command ...
# The size command affects the size of the graph.
# * **How many variables are being displayed in this graph?**
# There are ... variables being displayed in this graph.
# there are 3 variables being displayed in this graph.

# %%
sns.relplot(x="height", y="weight", hue="gender", sizes=(40, 400), size="race", alpha=.5, palette="muted", height=10, data=cdc)

# %% [markdown]
# # **Splitting data sets**
#
# * In lab 1B, we learned that we can facet (or split) our data based on a categorical variable.
# * Use the following code in a Code  block (green below)
#
# ---
#
#
# `sns.relplot(x="height", y="weight", hue="gender", sizes=(40, 400), size="race", alpha=.5, palette="muted", height=10, data=cdc)`
#
#
# ---
#
# * **What does the data show?**
# The data shows ...
# The data shows a scatterplot
# * **What do you think the size command in the code does?**
# The size command ...
# the size affects the of the dot's size.
# * **How many variables are being displayed in this graph?**
# There are 4 variables being displayed in this graph.

# %% [markdown]
# **Lets "Facet" this scatter plot.**
#
# The above scatter plot is useful, but theres a lot of information on it!   Use the following code in a Cell block and answer the questions below.
#
#
#
# ---
#
# `sns.relplot(x="height", y="weight", hue="gender", sizes=(40, 400), size="race", alpha=.5, palette="muted", col="gender", height=10, data=cdc)`
#
#
# ---

# %%
sns.relplot(x="height", y="weight", hue="gender", sizes=(10, 400), size="race", alpha=.5, palette="muted", col="gender", height=10, data=cdc)

# %% [markdown]
# * **What does each plot show?** One plot shows .... .  Tzhe other plot shows ...
# One plot shows men's weight and height while the other shows women's height and weight.
# * **Modify the "alpha" value - what do you think alpha does?**
# The alpha affects the clarity of the graph
# * **Copy the code from above to the code cell below.  Change the "col=" to another categorical variable.  What do you notice?**  It splits the data and affects the variables on the graph.

# %%
sns.relplot(x="height", y="weight", hue="gender", sizes=(40, 400), size="race", alpha=.5, palette="muted", col="hours_videogame", height=10, data=cdc)

# %% [markdown]
# # **Subsetting**
#
# * Subsetting is a term we use to describe the process of looking at only the data that conforms to some set of rules:
#  * Geologists may subset earthquake data by looking at only large earthquakes.
#  *  Stock market traders may subset their trading data by looking only at the previous day's trades.
#
# * There's many ways to subset data in python, we'll focus on learning the most common methods.
# * **We can filter on variables AND/OR observations.**

# %% [markdown]
# # **The filter function - filtering observations**
#
# * Creating two plots, one for male and female is useful.  But what if we want to examine only one group by itself?
# * **Start by creating a subset of the data.  Use the code below in a code cell block.**
#
#
# ---
#
# `cdc_male = cdc[cdc['gender']=="Male"]`
#
# ---

# %%
cdc_male = cdc[cdc['gender']=="Male"]

# %% [markdown]
# **Reuse your scatterplot from above**, but this time use **cdc_male** for your data="....."
#
#
#
# ```
# sns.relplot(x="height", y="weight", hue="gender", sizes=(40, 400), size="race", alpha=.5, palette="muted", height=10, data=cdc)
# ```

# %%
sns.relplot(x="height", y="weight", hue="gender", sizes=(40, 400), size="race", alpha=.5, palette="muted", height=10, data=cdc_male)

# %% [markdown]
# **Create a variable called cdc_female, and filter your dataset to only show females in your data.  Then, create a scatter plot to display only female data.**

# %%
cdc_female = cdc[cdc['gender']=="Female"]

# %%
sns.relplot(x="height", y="weight", hue="gender", sizes=(40, 400), size="race", alpha=.5, palette="muted", height=10, data=cdc_female)

# %% [markdown]
# # **Saving our subset**
#
#
# ---
#
# `cdc_male = cdc[cdc['gender']=="Male"]`
#
# ---
#
#
# * This code then:
#  * takes our subset data, (everything to the right of "=") ...
#  * and assigns the subset data, by using the arrow "=" ...
#  * the name cdc_male
#
# * We can now use cdc_male to do anything we could do with the regular cdc data ...
#  * but only including those students who reported being male.
#
#
#  **=** is the "assignment" operator.
#
#  **==** is the "equals to" operator.

# %% [markdown]
# ## **Multiple Filters**
#
# * We often want to filter our data based on muiltiple rules.
#  * for instance, we might want to filter data based on grade AND gender, or gender AND depression, or gender AND days_vaping
#
#
# ---
#
# ` cdc[(cdc['gender'] == "Male") & (cdc['bully_school'] == 'Yes')]`
#
# ---
#
# * **Filter your data's observations on two different variables.  Don't use the ones above.**

# %%
cdc[(cdc['gender'] == "Male") & (cdc['hours_videogame'] == '5 or more hours per day')]
# Out:
#        Unnamed: 0                    age  ...      drink_water sunburns
# 0               1           16 years old  ...   1 time per day  0 times
# 5               6  18 years old or older  ...     1 to 3 times  2 times
# 6               7  18 years old or older  ...  3 times per day  0 times
# 14             15           16 years old  ...   1 time per day  2 times
# 42             43  18 years old or older  ...   1 time per day  1 times
# ...           ...                    ...  ...              ...      ...
# 15562       15563           14 years old  ...              NaN      NaN
# 15569       15570           17 years old  ...              NaN      NaN
# 15584       15585           17 years old  ...              NaN      NaN
# 15610       15611           15 years old  ...              NaN      NaN
# 15613       15614           16 years old  ...              NaN      NaN
#
# [1415 rows x 34 columns]

# %% [markdown]
# # **Putting it all together**
#
# You are a researcher studying the habits of high school students.  **Come up with one question you'd like to investigate based on what we did today during our lab.** You must include in your answer - at least one histogram and at least one filter on your dataset.

# %% [markdown]
# The question I will investigate is who exercise more? Males or Females?
#
# According to our data, males reported that they workout for at leas

# %%
sns.countplot(y="days_exercise_60", hue="gender", data=cdc)
